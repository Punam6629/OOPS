# %% [markdown]
# **Oops Assignment**

# %% [markdown]
# 1.  What is Object-Oriented Programming (OOP).
# - Object-Oriented Programming (OOP) is a programming paradigm based on the concept of "objects," which can contain data and code to manipulate that data. OOP allows developers to structure software in a way that models real-world entities and their interactions. This approach promotes modularity, code reuse, and scalability in software development.
# 2. What is a class in OOP ?
# - In object-oriented programming (OOP), a class is a template that defines the methods and variables for a specific type of object:
# - Definition
# - A class is a user-defined data type that acts as a blueprint for creating objects.
# - Purpose
# - Classes are used to organize data so that programmers can reuse elements in multiple instances.
# - Structure
# - A class defines the shared aspects of objects created from it, such as state (variables) and behavior (methods).
# -Inheritance
# - Classes can have subclasses that inherit all or some of the characteristics of the class. The class that a subclass is based on is called the superclass.
# 3. What is an object in OOP ?
# - In object-oriented programming (OOP), an object is a fundamental unit of code that is a data structure with methods and fields:
# - Data: Fields, also known as properties, attributes, or members, contain data.
# - Methods: Subroutines or procedures that define how the object behaves in code.
# Class and Object in OOP - DEV Community
# - Objects are the basic building blocks of OOP applications. They are created using classes, which define their structure. Objects can interact with each other through defined interfaces.
# 4. What is the difference between abstraction and encapsulation ?
# - 1. Abstraction:
# - Definition:
# Abstraction focuses on hiding the implementation details of an object and exposing only the essential features or functionalities. It deals with the what an object does rather than how it does it.
# - Purpose:
# To simplify the complexity of a system by only showing relevant information and hiding unnecessary details.
# - Implementation:
# Achieved using abstract classes, interfaces, or methods in languages like Java, Python, or C++.
# - Example:
# ATM Machine: You use an ATM to withdraw cash by pressing a few buttons. You don't need to know the internal workings of the machine, such as how it communicates with the bank server.
# 2. Encapsulation:
# - Definition:
# Encapsulation is the mechanism of hiding an object's internal state and requiring all interaction to be performed through an object's methods. It protects the object's data from unauthorized access and modification.
# - Purpose:
# To achieve data security and prevent unintended interference.
# - Implementation:
# Achieved by using access modifiers such as private, protected, and public to control access to class members.
# - Example:
# Capsule in Medicine: The ingredients inside a capsule are hidden, and you only interact with it by consuming the outer shell.
# 5.  What are dunder methods in Python?
# - Dunder methods, short for "double underscore methods," are special methods in Python that begin and end with double underscores (__). They are also known as "magic methods" or "special methods." These methods enable the customization of the behavior of Python objects and provide hooks into Python's built-in features.
# - Dunder methods allow you to define how objects of a class interact with built-in functions, operators, and Python's syntax. For example, they can be used to customize string representation, arithmetic operations, comparisons, and more.
# 6. Explain the concept of inheritance in OOP?
# - Inheritance is a fundamental concept in object-oriented programming (OOP) that allows a class to inherit properties and behaviors from another class:
# - Explanation:
# A class that inherits from another class is called a subclass or derived class, while the class being inherited is called the parent class, superclass, or base class.
# - Benefits:
# Inheritance allows for code reuse, which minimizes redundancy and promotes efficient codebases. It also establishes a clear relationship between classes, which provides a structured approach to building and extending classes.
# - Examples:
# For example, a Strawberry class could inherit from a Fruit class, allowing it to use the Fruit class's public properties and methods. The Strawberry class could also add its own methods.
# - Some common types of inheritance include single, multiple, multilevel, hierarchical, and hybrid inheritance.
# 7. What is polymorphism in OOP ?
# - Polymorphism is a key concept in OOP that allows objects of different classes to be treated as objects of a common parent class. It enables the same method or operation to behave differently depending on the object it is acting upon. The term "polymorphism" means "many forms."
# 8.  How is encapsulation achieved in Python ?
# - In Python, encapsulation is achieved by using access modifiers to limit access to a class's variables and methods:
# - Public:
# Attributes and methods are public by default, meaning they can be accessed from outside the class.
# - Private:
# Use a double underscore prefix (__) to make an attribute private. Private members are only accessible within the class and are intended for internal use.
# - Protected:
# Use a single underscore prefix (_) to indicate that an attribute is meant for internal use within the class and its subclass. Protected members are not as strictly enforced as private members.
# - Encapsulation is a programming technique that bundles a class's data and methods into a single unit. It helps to: Promote code reusability, Maintain code, Improve security, Reduce the risk of accidental data modification, and Make it easier to modify or extend functionality.
# - Python's encapsulation is convention-based, rather than strictly enforced by the language. However, adhering to these conventions is important for maintaining clean and maintainable code.
# 9. What is a constructor in Python ?
# - In Python, a constructor is a special method that is automatically called when a new object is created from a class:
# - Purpose:
# The main purpose of a constructor is to initialize the attributes of an object when it is created.
# - Name:
# The name of the constructor method is always __init__.
# - How it works:
# The __init__ method is called with the newly created object as the first argument, and any additional arguments are passed to the class constructor. The self keyword can then be used to initialize the object's attributes.
# - Types of constructors:
# There are different types of constructors, including default constructors and parameterized constructors. A default constructor doesn't accept any arguments, while a parameterized constructor takes additional arguments from the programmer.
# - Importance:
# Constructors are a foundation of object-oriented programming and are important for streamlining object initialization and optimizing memory usage.
# 10. What are class and static methods in Python?
# - A . Class Methods
# A class method is a method that is bound to the class and not the instance of the class. It takes a class reference (cls) as its first argument instead of an instance reference (self), which allows it to modify class-level attributes rather than instance-level attributes.
# - Syntax: @classmethod decorator
# - Usage: Class methods are used when you need to operate on the class itself rather than an instance of the class, such as modifying class variables or creating factory methods.
# - B. Static Methods
# A static method is a method that does not take any special first argument (self or cls). It behaves like a regular function but belongs to the class’s namespace. Static methods do not have access to the instance or the class, but they can still be called on the class or the instance.
# - Syntax: @staticmethod decorator
# - Usage: Static methods are useful when you want to include functionality that is related to the class but does not need to access or modify instance or class-level data.
# 11. What is method overloading in Python?
# - Method Overloading is a feature in some object-oriented programming languages that allows multiple methods with the same name to be defined, each differing in the number or type of their arguments. However, Python does not natively support traditional method overloading like other languages such as Java or C++. In Python, the last method definition with the same name simply overrides the previous ones.
# However, you can simulate method overloading in Python by using default arguments or variable-length argument lists.
# 12. What is method overriding in OOP?
# - Method Overriding is a feature in OOP that allows a subclass to provide a specific implementation of a method that is already defined in its parent class. The new implementation in the subclass overrides the parent class method, which allows for more specific or customized behavior in the subclass.
#
# 13. What is a property decorator in Python?
# - In Python, the @property decorator is used to define a method as a getter for an attribute. It allows you to access a method like an attribute without explicitly calling it as a method. This helps in making the code more readable and is a way to implement encapsulation.
# - The @property decorator provides a getter for an attribute, and you can also define setter and deleter methods associated with that attribute.
# 14.  Why is polymorphism important in OOP?
# - Polymorphism is a core feature of object-oriented programming (OOP) languages that allows for code reusability, flexibility, and extensibility. It's important because it allows programmers to:
# - Reuse code:
# Polymorphism allows programmers to reuse code, which saves time and speeds up development.
# - Improve readability :
# Polymorphism can improve code readability by allowing functions to share the same name but have different arguments.
# - Extend programs:
# Polymorphism makes it easier to extend or change aspects of programs without affecting the entire program.
# - Store multiple data types:
# Polymorphism allows all major data types to be stored in a single variable.
# - Simplify debugging:
# Polymorphism simplifies code debugging.
# 15. What is an abstract class in Python?
# - An abstract class in Python is a class that cannot be instantiated directly and is meant to be subclassed by other classes. It serves as a blueprint for other classes. Abstract classes allow you to define methods that must be implemented by subclasses, ensuring that those subclasses follow a certain structure or contract.
#
# - Abstract classes are part of Python's abc (Abstract Base Classes) module, which provides the infrastructure for defining and working with abstract classes.
#
# 16 . What are the advantages of OOP?
# -  Advantages of OOP:
# - A . Modularity: Makes it easier to break a program into smaller, manageable pieces.
# - B . Reusability: Enables reuse of code through inheritance and polymorphism.
# - C .Scalability: Facilitates the growth of systems by allowing easy extension and modification.
# - D . Abstraction: Hides the complexity and exposes only relevant details.
# Encapsulation: Protects data and ensures safe manipulation.
# - E . Polymorphism: Increases flexibility and reduces complexity in code.
# Maintainability: Easier to modify and extend without breaking other parts of the system.
# - F . Data Security: Ensures proper access control and data protection.
# Improved Collaboration: Supports teamwork with modular and standardized design.
# - G . Testability: Makes testing more straightforward by isolating components.
#
# 17. What is the difference between a class variable and an instance variable?
# - 1. Class Variables
# - Definition: A class variable is a variable that is shared among all instances of a class. It is defined within the class but outside any instance methods (including __init__).
# - Scope: Class variables belong to the class itself, not to any specific instance of the class.
# - Access: Class variables are accessed using the class name or through an instance, but the value is shared by all instances.
# - Modification: Any change to a class variable through one instance will affect all other instances of the class unless the variable is overridden at the instance level.
# - Example: Typically used for values or constants that should be the same across all instances of a class.
# 2. Instance Variables
# - Definition: An instance variable is a variable that is specific to each instance of the class. It is defined inside methods (often in the __init__ constructor) and is prefixed with self to indicate it belongs to a particular object.
# - Scope: Instance variables belong to individual objects created from the class. Each instance of the class can have its own separate value for instance variables.
# - Access: Instance variables are accessed using the instance (not the class).
# Modification: Modifying an instance variable only affects the specific instance, not other instances of the class.
# - Example: Typically used for attributes that are specific to each object.
#
# 18 . What is multiple inheritance in Python?
# - Multiple Inheritance in Python
# - Multiple inheritance is a feature in object-oriented programming where a class can inherit from more than one base class. This allows the derived class to inherit attributes and methods from multiple parent classes, combining their functionality.
# - In Python, a class can inherit from multiple classes by listing them in parentheses in the class definition. This feature enables a class to reuse code from more than one source, making it possible to create more complex and specialized behavior.
#
# 19. Explain the purpose of ‘’_str_’ and ‘_rep_’ ‘ methods in Python.
# - str__ Method
# - The __str__ method is used to define the user-friendly or informal string representation of an object. This is the method that gets called when you use the str() function or the print() function on an object. Its primary goal is to provide a readable and friendly output that is easy to understand for humans.
# - Purpose: For human-readable output.
# - When it is called: When you use str() or print() on an object.
# - __repr__ Method
# The __repr__ method is used to define the formal string representation of an object. Its primary goal is to provide an unambiguous string that, if passed to eval(), would ideally recreate the object. This method is often used for debugging and logging because it provides a more detailed and precise representation of the object, which is helpful for developers.
# - Purpose: For developer-friendly or unambiguous output, primarily for debugging.
# - When it is called: When you use repr() or print an object in the interactive interpreter.
#
# 20 . What is the significance of the ‘super()’ function in Python?
# - The super() function in Python is used to call methods from a parent (or superclass) class from within a derived (or subclass) class. It is a built-in function that allows you to invoke the methods of a superclass without explicitly naming the class, making the code more maintainable and avoiding direct reference to parent classes. This is particularly useful in cases of inheritance and multiple inheritance.
#
# - Significance of super()
# - Accessing Parent Class Methods:
# It allows a subclass to call methods from its superclass. This is especially useful in overriding methods, where you may want to extend or modify the functionality of a method defined in the superclass rather than completely replacing it.
# - Avoiding Hardcoding Parent Class Names:
# Using super() eliminates the need to explicitly mention the parent class's name. This makes your code more flexible and easier to maintain, especially when working with multiple inheritance, where a class may inherit from more than one parent.
# - Method Resolution Order (MRO) in Multiple Inheritance:
# In Python, when a class is derived from multiple classes, the Method Resolution Order (MRO) determines the order in which the classes are searched for a method. super() ensures that the method resolution follows the correct MRO, preventing conflicts and ambiguity.
# - Calling the Constructor of Parent Classes:
# super() is commonly used in the __init__() constructor method to call the constructor of the parent class, ensuring that initialization from the base class is properly invoked.
#
# 21 . What is the significance of the __del__ method in Python?
# -
# The __del__ method in Python is a special method (also called a dunder method) that is used to define the destructor behavior of an object. It is automatically invoked when an object is about to be destroyed, typically when it is garbage collected. The primary purpose of __del__ is to allow objects to perform clean-up activities such as closing files, releasing network connections, or other resources before the object is removed from memory.
#
# - Significance of __del__ Method
# - Resource Cleanup:
# The __del__ method can be used to clean up external resources that the object may have acquired during its lifetime, such as files, database connections, or network sockets. This ensures that these resources are properly released when the object is no longer needed.
# - Automatic Invocation:
# Python automatically calls __del__ when an object is about to be garbage collected, i.e., when there are no more references to the object. This is a convenient way to perform cleanup without having to explicitly call a method from the user code.
# - Memory Management:
# Although Python uses automatic memory management with garbage collection, __del__ allows you to define how an object should release resources before it is destroyed. For example, it can be used to close files that were opened or free memory from external resources.
#
# 22 . What is the difference between @staticmethod and @classmethod in Python?
# - @staticmethod
# - Definition: A static method does not take any reference to the instance (self) or the class (cls) as its first argument. It behaves like a regular function that belongs to the class's namespace, but it doesn't have access to instance or class-level data.
# - Use case: Use @staticmethod when you need a method that logically belongs to the class but doesn't need to access or modify any instance-specific (self) or class-specific (cls) data. It is independent of object state and is often used - for utility functions.
# - Calling: A static method can be called using both an instance and the class itself.
# - @classmethod
# - Definition: A class method takes a reference to the class (cls) as its first argument instead of the instance (self). This allows the method to access or modify class-level attributes and methods. A class method is bound to the class and not the instance.
# - Use case: Use @classmethod when you need a method that operates on class-level data (i.e., attributes or methods shared among all instances of the class) or needs to create instances of the class (as seen in factory methods).
# - Calling: A class method can be called using both an instance and the class itself, but it always takes the class (cls) as the first argument.
#
# 23 . How does polymorphism work in Python with inheritance?
# - Polymorphism in Python is the ability of different classes to define methods with the same name, which behave differently based on the object instance. This feature is often utilized with inheritance to enable objects of different classes to be treated uniformly. Here's a breakdown of how polymorphism works in Python with inheritance:
# 1. Polymorphism with Methods in Derived Classes
# - When a method in a derived class has the same name as a method in the base class, the method in the derived class overrides the one in the base class.
# - This allows the derived class to provide its own implementation of the method.
# 2. Polymorphism with Function Arguments :
# You can write functions that operate on objects of different types, as long as they support the required methods or behaviors.
# 3. Polymorphism with Abstract Base Classes (ABCs)
# - Python's abc module can be used to define abstract base classes, ensuring that derived classes implement specific methods.
# - This provides a more structured way to enforce polymorphic behavior.
#
# 24 .  What is method chaining in Python OOP?
# - Method chaining in Python Object-Oriented Programming (OOP) is a programming technique where multiple methods are called on the same object in a single statement. This is accomplished by ensuring that each method in the chain returns the object itself (or another object with methods that can continue the chain).
#
# 25 . What is the purpose of the __call__ method in Python?
# - The __call__ method in Python allows an instance of a class to be called as if it were a function. When you define a __call__ method in a class, you can invoke objects of that class with the same syntax as calling a regular function. This feature is especially useful for creating objects that behave like functions, also known as "callable objects."
# - Purpose of __call__:
# - Enhance Readability: It allows objects to be used in a concise and intuitive way.
# - Encapsulation: You can encapsulate complex logic or state inside an object while keeping a simple, function-like interface.
# - Functional Interfaces: It is commonly used to implement APIs or utilities where the object needs to behave like a function but also maintains internal state.

# %%
# 1 . . Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!"
'''
# Parent class
class Animal:
    def speak(self):
        print("This animal makes a sound.")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Example usage
animal = Animal()
dog = Dog()

animal.speak()  # Outputs: This animal makes a sound.
dog.speak()     # Outputs: Bark!'''

# %%
# 2 . Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both.
'''
from abc import ABC, abstractmethod
import math

# Abstract base class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Derived class: Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Derived class: Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example usage
circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Area of the circle: {circle.area():.2f}")  # Outputs: Area of the circle: 78.54
print(f"Area of the rectangle: {rectangle.area()}")  # Outputs: Area of the rectangle: 24
'''

# %%
# 3 .  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute.
'''
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def display_type(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# Intermediate class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def display_car_info(self):
        print(f"Brand: {self.brand}")

# Derived class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def display_electric_car_info(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Example usage
vehicle = Vehicle("Generic Vehicle")
vehicle.display_type()

car = Car("Car", "Toyota")
car.display_type()
car.display_car_info()

electric_car = ElectricCar("Electric Car", "Tesla", 75)
electric_car.display_type()
electric_car.display_car_info()
electric_car.display_electric_car_info()
Output=Vehicle Type: Generic Vehicle
Vehicle Type: Car
Brand: Toyota
Vehicle Type: Electric Car
Brand: Tesla
Battery Capacity: 75 kWh
'''

# %%
# 4 . Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute.
'''
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def display_type(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# Intermediate class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def display_car_info(self):
        print(f"Vehicle Type: {self.vehicle_type}, Brand: {self.brand}")

# Derived class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def display_electric_car_info(self):
        print(f"Vehicle Type: {self.vehicle_type}, Brand: {self.brand}, Battery Capacity: {self.battery_capacity} kWh")

# Example usage
vehicle = Vehicle("General Vehicle")
vehicle.display_type()

car = Car("Car", "Toyota")
car.display_car_info()

electric_car = ElectricCar("Electric Car", "Tesla", 100)
electric_car.display_electric_car_info()
Output= Vehicle Type: General Vehicle
Vehicle Type: Car, Brand: Toyota
Vehicle Type: Electric Car, Brand: Tesla, Battery Capacity: 100 kWh
'''

# %%
# 5 . Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance.
'''
class BankAccount:
    def __init__(self, account_holder, initial_balance=0):
        self.__balance = initial_balance  # Private attribute
        self.account_holder = account_holder

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount:.2f}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.__balance:
                self.__balance -= amount
                print(f"Withdrew: ${amount:.2f}")
            else:
                print("Insufficient balance.")
        else:
            print("Withdrawal amount must be positive.")

    def check_balance(self):
        print(f"Account holder: {self.account_holder}")
        print(f"Current Balance: ${self.__balance:.2f}")

# Example usage
account = BankAccount("John Doe", 500)

# Deposit money
account.deposit(200)

# Check balance
account.check_balance()

# Withdraw money
account.withdraw(100)

# Check balance again
account.check_balance()

# Attempt to access the private attribute directly (should raise an error or be inaccessible)
# print(account.__balance)  # Uncommenting this line will result in an AttributeError
Output= Deposited: $200.00
Account holder: John Doe
Current Balance: $700.00
Withdrew: $100.00
Account holder: John Doe
Current Balance: $600.00
'''

# %%
# 6 .  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play().
'''
# Base class
class Instrument:
    def play(self):
        print("Playing the instrument...")

# Derived class: Guitar
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar...")

# Derived class: Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano keys...")

# Example usage
def perform_music(instrument):
    instrument.play()  # Runtime polymorphism: the actual play() depends on the object type

# Creating objects
guitar = Guitar()
piano = Piano()
generic_instrument = Instrument()

# Demonstrating polymorphism
perform_music(guitar)            # Outputs: Strumming the guitar...
perform_music(piano)             # Outputs: Playing the piano keys...
perform_music(generic_instrument)  # Outputs: Playing the instrument...
'''

# %%
# 7 .  Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers.
'''
class MathOperations:
    @classmethod
    def add_numbers(cls, num1, num2):
        """Class method to add two numbers."""
        return num1 + num2

    @staticmethod
    def subtract_numbers(num1, num2):
        """Static method to subtract two numbers."""
        return num1 - num2

# Example usage
# Using the class method
result_add = MathOperations.add_numbers(10, 5)
print(f"Addition: {result_add}")  # Outputs: Addition: 15

# Using the static method
result_subtract = MathOperations.subtract_numbers(10, 5)
print(f"Subtraction: {result_subtract}")  # Outputs: Subtraction: 5
'''

# %%
# 8 . Implement a class Person with a class method to count the total number of persons created.
'''
class Person:
    # Class attribute to keep track of the count
    total_persons = 0

    def __init__(self, name, age):
        self.name = name
        self.age = age
        # Increment the count whenever a new instance is created
        Person.total_persons += 1

    @classmethod
    def count_persons(cls):
        """Class method to return the total number of persons created."""
        return cls.total_persons

# Example usage
person1 = Person("Alice", 30)
person2 = Person("Bob", 25)

# Using the class method to count the total number of persons
print(f"Total persons created: {Person.count_persons()}")  # Outputs: Total persons created: 2

person3 = Person("Charlie", 22)

# Checking the total number of persons again
print(f"Total persons created: {Person.count_persons()}")  # Outputs: Total persons created: 3
'''

# %%
# 9 .  Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator".
'''
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        # Override the __str__ method to display the fraction
        return f"{self.numerator}/{self.denominator}"

# Example usage
fraction1 = Fraction(3, 4)
fraction2 = Fraction(5, 8)

# Print the fractions using the overridden __str__ method
print(fraction1)  # Outputs: 3/4
print(fraction2)  # Outputs: 5/8
'''

# %%
# 10 .  Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors.
'''
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        """Override the + operator to add two vectors."""
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        return NotImplemented

    def __str__(self):
        """Override the str method to display the vector."""
        return f"({self.x}, {self.y})"

# Example usage
vector1 = Vector(2, 3)
vector2 = Vector(4, 5)

# Adding two vectors using the overloaded + operator
result_vector = vector1 + vector2

# Displaying the result
print(f"Result of addition: {result_vector}")  # Outputs: Result of addition: (6, 8)
'''

# %%
# 11 .  Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old."
'''
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        """Method to greet with the person's name and age."""
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example usage
person1 = Person("Alice", 30)
person2 = Person("Bob", 25)

# Calling the greet method
person1.greet()  # Outputs: Hello, my name is Alice and I am 30 years old.
person2.greet()  # Outputs: Hello, my name is Bob and I am 25 years old.
'''

# %%
# 12 .  Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades.
'''
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # List of grades

    def average_grade(self):
        """Method to compute the average of the grades."""
        if len(self.grades) == 0:
            return 0  # Avoid division by zero if no grades are provided
        return sum(self.grades) / len(self.grades)

# Example usage
student1 = Student("Alice", [85, 90, 78, 92, 88])
student2 = Student("Bob", [75, 80, 85])

# Computing the average grades
print(f"{student1.name}'s average grade: {student1.average_grade():.2f}")  # Outputs: Alice's average grade: 86.60
print(f"{student2.name}'s average grade: {student2.average_grade():.2f}")  # Outputs: Bob's average grade: 80.00
'''

# %%
# 13 .  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area.
'''
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        """Method to set the dimensions of the rectangle."""
        self.length = length
        self.width = width

    def area(self):
        """Method to calculate and return the area of the rectangle."""
        return self.length * self.width

# Example usage
rectangle1 = Rectangle()

# Setting dimensions for the rectangle
rectangle1.set_dimensions(5, 3)

# Calculating the area
print(f"Area of rectangle: {rectangle1.area()}")  # Outputs: Area of rectangle: 15
'''

# %%
# 14 . Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary.
'''
# Base class: Employee
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        """Method to calculate the salary based on hours worked and hourly rate."""
        return self.hours_worked * self.hourly_rate

# Derived class: Manager
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        """Override the calculate_salary method to add the bonus."""
        base_salary = super().calculate_salary()  # Call the base class method
        return base_salary + self.bonus

# Example usage
employee = Employee("John Doe", 40, 20)  # 40 hours, $20/hour
manager = Manager("Jane Smith", 45, 25, 500)  # 45 hours, $25/hour, $500 bonus

# Calculating salaries
print(f"{employee.name}'s salary: ${employee.calculate_salary()}")  # Outputs: John Doe's salary: $800
print(f"{manager.name}'s salary: ${manager.calculate_salary()}")  # Outputs: Jane Smith's salary: $1250
'''

# %%
# 15 .  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product.
'''
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        """Method to calculate the total price of the product."""
        return self.price * self.quantity

# Example usage
product1 = Product("Laptop", 1000, 2)
product2 = Product("Phone", 500, 5)

# Calculating the total price for each product
print(f"Total price of {product1.name}: ${product1.total_price()}")  # Outputs: Total price of Laptop: $2000
print(f"Total price of {product2.name}: ${product2.total_price()}")  # Outputs: Total price of Phone: $2500
'''

# %%
# 16 .  Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method.
'''
from abc import ABC, abstractmethod

# Abstract base class: Animal
class Animal(ABC):
    @abstractmethod
    def sound(self):
        """Abstract method that must be implemented by subclasses."""
        pass

# Derived class: Cow
class Cow(Animal):
    def sound(self):
        """Implement the sound() method for Cow."""
        print("Moo!")

# Derived class: Sheep
class Sheep(Animal):
    def sound(self):
        """Implement the sound() method for Sheep."""
        print("Baa!")

# Example usage
cow = Cow()
sheep = Sheep()

# Calling the sound method
cow.sound()  # Outputs: Moo!
sheep.sound()  # Outputs: Baa!
'''

# %%
# 17 . Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details.
'''
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        """Method to return a formatted string with the book's details."""
        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

# Example usage
book1 = Book("The Great Gatsby", "F. Scott Fitzgerald", 1925)
book2 = Book("1984", "George Orwell", 1949)

# Getting book info
print(book1.get_book_info())
# Outputs:
# Title: The Great Gatsby
# Author: F. Scott Fitzgerald
# Year Published: 1925

print(book2.get_book_info())
# Outputs:
# Title: 1984
# Author: George Orwell
# Year Published: 1949
'''

# %%
# 18 .  Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms.
'''
# Base class: House
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def display_info(self):
        """Method to display the basic information of the house."""
        return f"Address: {self.address}\nPrice: ${self.price}"

# Derived class: Mansion
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)  # Call the parent class constructor
        self.number_of_rooms = number_of_rooms

    def display_info(self):
        """Override to include the number of rooms in the display."""
        basic_info = super().display_info()  # Get the information from the base class
        return f"{basic_info}\nNumber of Rooms: {self.number_of_rooms}"

# Example usage
house = House("123 Main St, Small Town", 250000)
mansion = Mansion("456 Luxury Ave, Grand City", 5000000, 15)

# Displaying information for both House and Mansion
print("House Info:")
print(house.display_info())
# Outputs:
# Address: 123 Main St, Small Town
# Price: $250000

print("\nMansion Info:")
print(mansion.display_info())
# Outputs:
# Address: 456 Luxury Ave, Grand City
# Price: $5000000
# Number of Rooms: 15
'''
